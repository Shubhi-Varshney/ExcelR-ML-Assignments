# %% [markdown]
# ### Prepare a classification model using SVM for salary data
#
# #### Data Description:
#
# #### age -- age of a person
# #### workclass	-- A work class is a grouping of work
# #### education	-- Education of an individuals
# #### maritalstatus -- Marital status of an individulas
# #### occupation	 -- occupation of an individuals
# #### relationship --
# #### race --  Race of an Individual
# #### sex --  Gender of an Individual
# #### capitalgain --  profit received from the sale of an investment
# #### capitalloss	-- A decrease in the value of a capital asset
# #### hoursperweek -- number of hours work per week
# #### native -- Native of an individual
# #### Salary -- salary of an individual

# %%
# Importing libraries
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# importing the training data
data_train = pd.read_csv('SalaryData_Train.csv')
data_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
# importing the test data
data_test = pd.read_csv('SalaryData_Test.csv')
data_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
data_train['workclass'].value_counts()
# Out:
#  Private             22285
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: workclass, dtype: int64

# %%
data_test['workclass'].value_counts()
# Out:
#  Private             11021
#  Self-emp-not-inc     1297
#  Local-gov            1033
#  State-gov             667
#  Self-emp-inc          572
#  Federal-gov           463
#  Without-pay             7
# Name: workclass, dtype: int64

# %%
# Want to ensure the categories are same in both trainng and testing data
train_object_cols = [cname for cname in data_train.columns if data_train[cname].dtype == 'object']
test_object_cols =  [cname for cname in data_test.columns  if data_test[cname].dtype == 'object']

print(train_object_cols)
print(test_object_cols)

if(train_object_cols == test_object_cols):
    print('Equal')
    
# Tried with other method of equality
if(np.array_equal(train_object_cols, test_object_cols)):
    print('Again equal')
# Out:
# ['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native', 'Salary']
# ['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native', 'Salary']
# Equal
# Again equal

# %% [markdown]
# ## Since training and test are similar datasets..We will do data analysis on one data first and then apply the same transformations on testing data.

# %%
data_train.groupby(['education', 'educationno']).count()
# Out:
#                             age  workclass  maritalstatus  occupation  \
# education     educationno
#  10th         6             820        820            820         820
#  11th         7            1048       1048           1048        1048
#  12th         8             377        377            377         377
#  1st-4th      2             151        151            151         151
#  5th-6th      3             288        288            288         288
#  7th-8th      4             557        557            557         557
#  9th          5             455        455            455         455
#  Assoc-acdm   12           1008       1008           1008        1008
#  Assoc-voc    11           1307       1307           1307        1307
#  Bachelors    13           5044       5044           5044        5044
#  Doctorate    16            375        375            375         375
#  HS-grad      9            9840       9840           9840        9840
#  Masters      14           1627       1627           1627        1627
#  Preschool    1              45         45             45          45
#  Prof-school  15            542        542            542         542
#  Some-college 10           6677       6677           6677        6677
#
#                            relationship  race   sex  capitalgain  capitalloss  \
# education     educationno
#  10th         6                     820   820   820          820          820
#  11th         7                    1048  1048  1048         1048         1048
#  12th         8                     377   377   377          377          377
#  1st-4th      2                     151   151   151          151          151
#  5th-6th      3                     288   288   288          288          288
#  7th-8th      4                     557   557   557          557          557
#  9th          5                     455   455   455          455          455
#  Assoc-acdm   12                   1008  1008  1008         1008         1008
#  Assoc-voc    11                   1307  1307  1307         1307         1307
#  Bachelors    13                   5044  5044  5044         5044         5044
#  Doctorate    16                    375   375   375          375          375
#  HS-grad      9                    9840  9840  9840         9840         9840
#  Masters      14                   1627  1627  1627         1627         1627
#  Preschool    1                      45    45    45           45           45
#  Prof-school  15                    542   542   542          542          542
#  Some-college 10                   6677  6677  6677         6677         6677
#
#                            hoursperweek  native  Salary
# education     educationno
#  10th         6                     820     820     820
#  11th         7                    1048    1048    1048
#  12th         8                     377     377     377
#  1st-4th      2                     151     151     151
#  5th-6th      3                     288     288     288
#  7th-8th      4                     557     557     557
#  9th          5                     455     455     455
#  Assoc-acdm   12                   1008    1008    1008
#  Assoc-voc    11                   1307    1307    1307
#  Bachelors    13                   5044    5044    5044
#  Doctorate    16                    375     375     375
#  HS-grad      9                    9840    9840    9840
#  Masters      14                   1627    1627    1627
#  Preschool    1                      45      45      45
#  Prof-school  15                    542     542     542
#  Some-college 10                   6677    6677    6677

# %%
# will drop education column as it is kind of label encoded already and gives redundatant information
data_train.drop(['education'], axis=1, inplace=True)
data_train.head()
# Out:
#    age          workclass  educationno        maritalstatus  \
# 0   39          State-gov           13        Never-married
# 1   50   Self-emp-not-inc           13   Married-civ-spouse
# 2   38            Private            9             Divorced
# 3   53            Private            7   Married-civ-spouse
# 4   28            Private           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
train_object_cols.remove('education')

# %%
# applying label Encoder to the training dataset

le = LabelEncoder()
for column in train_object_cols:
    data_train[column] = le.fit_transform(data_train[column])    

data_train.head()
# Out:
#    age  workclass  educationno  maritalstatus  occupation  relationship  race  \
# 0   39          5           13              4           0             1     4
# 1   50          4           13              2           3             0     4
# 2   38          2            9              0           5             1     4
# 3   53          2            7              2           5             0     2
# 4   28          2           13              2           9             5     2
#
#    sex  capitalgain  capitalloss  hoursperweek  native  Salary
# 0    1         2174            0            40      37       0
# 1    1            0            0            13      37       0
# 2    1            0            0            40      37       0
# 3    1            0            0            40      37       0
# 4    0            0            0            40       4       0

# %%
# Splitting the X and y variables
y_train = data_train.iloc[:,-1]
X_train = data_train.drop(['Salary'], axis=1)

# %%
X_train.head()
# Out:
#    age  workclass  educationno  maritalstatus  occupation  relationship  race  \
# 0   39          5           13              4           0             1     4
# 1   50          4           13              2           3             0     4
# 2   38          2            9              0           5             1     4
# 3   53          2            7              2           5             0     2
# 4   28          2           13              2           9             5     2
#
#    sex  capitalgain  capitalloss  hoursperweek  native
# 0    1         2174            0            40      37
# 1    1            0            0            13      37
# 2    1            0            0            40      37
# 3    1            0            0            40      37
# 4    0            0            0            40       4

# %%
y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Salary, dtype: int32

# %% [markdown]
# ### Will apply the same transformations on the testing data

# %%
data_test.groupby(['education', 'educationno']).count()
# Out:
#                             age  workclass  maritalstatus  occupation  \
# education     educationno
#  10th         6             403        403            403         403
#  11th         7             571        571            571         571
#  12th         8             200        200            200         200
#  1st-4th      2              71         71             71          71
#  5th-6th      3             161        161            161         161
#  7th-8th      4             266        266            266         266
#  9th          5             221        221            221         221
#  Assoc-acdm   12            499        499            499         499
#  Assoc-voc    11            652        652            652         652
#  Bachelors    13           2526       2526           2526        2526
#  Doctorate    16            169        169            169         169
#  HS-grad      9            4943       4943           4943        4943
#  Masters      14            887        887            887         887
#  Preschool    1              27         27             27          27
#  Prof-school  15            243        243            243         243
#  Some-college 10           3221       3221           3221        3221
#
#                            relationship  race   sex  capitalgain  capitalloss  \
# education     educationno
#  10th         6                     403   403   403          403          403
#  11th         7                     571   571   571          571          571
#  12th         8                     200   200   200          200          200
#  1st-4th      2                      71    71    71           71           71
#  5th-6th      3                     161   161   161          161          161
#  7th-8th      4                     266   266   266          266          266
#  9th          5                     221   221   221          221          221
#  Assoc-acdm   12                    499   499   499          499          499
#  Assoc-voc    11                    652   652   652          652          652
#  Bachelors    13                   2526  2526  2526         2526         2526
#  Doctorate    16                    169   169   169          169          169
#  HS-grad      9                    4943  4943  4943         4943         4943
#  Masters      14                    887   887   887          887          887
#  Preschool    1                      27    27    27           27           27
#  Prof-school  15                    243   243   243          243          243
#  Some-college 10                   3221  3221  3221         3221         3221
#
#                            hoursperweek  native  Salary
# education     educationno
#  10th         6                     403     403     403
#  11th         7                     571     571     571
#  12th         8                     200     200     200
#  1st-4th      2                      71      71      71
#  5th-6th      3                     161     161     161
#  7th-8th      4                     266     266     266
#  9th          5                     221     221     221
#  Assoc-acdm   12                    499     499     499
#  Assoc-voc    11                    652     652     652
#  Bachelors    13                   2526    2526    2526
#  Doctorate    16                    169     169     169
#  HS-grad      9                    4943    4943    4943
#  Masters      14                    887     887     887
#  Preschool    1                      27      27      27
#  Prof-school  15                    243     243     243
#  Some-college 10                   3221    3221    3221

# %%
# will drop education column as it is kind of label encoded already and gives redundatant information
data_test.drop(['education'], axis=1, inplace=True)
data_test.head()
# Out:
#    age   workclass  educationno        maritalstatus          occupation  \
# 0   25     Private            7        Never-married   Machine-op-inspct
# 1   38     Private            9   Married-civ-spouse     Farming-fishing
# 2   28   Local-gov           12   Married-civ-spouse     Protective-serv
# 3   44     Private           10   Married-civ-spouse   Machine-op-inspct
# 4   34     Private            6        Never-married       Other-service
#
#      relationship    race    sex  capitalgain  capitalloss  hoursperweek  \
# 0       Own-child   Black   Male            0            0            40
# 1         Husband   White   Male            0            0            50
# 2         Husband   White   Male            0            0            40
# 3         Husband   Black   Male         7688            0            40
# 4   Not-in-family   White   Male            0            0            30
#
#            native  Salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States    >50K
# 3   United-States    >50K
# 4   United-States   <=50K

# %%
# Removing categorical column from object columns array
test_object_cols.remove('education')

# %%
for column in test_object_cols:
    data_test[column] = le.fit_transform(data_test[column])    

data_test.head()
# Out:
#    age  workclass  educationno  maritalstatus  occupation  relationship  race  \
# 0   25          2            7              4           6             3     2
# 1   38          2            9              2           4             0     4
# 2   28          1           12              2          10             0     4
# 3   44          2           10              2           6             0     2
# 4   34          2            6              4           7             1     4
#
#    sex  capitalgain  capitalloss  hoursperweek  native  Salary
# 0    1            0            0            40      37       0
# 1    1            0            0            50      37       0
# 2    1            0            0            40      37       1
# 3    1         7688            0            40      37       1
# 4    1            0            0            30      37       0

# %%
# Splitting the X and y variables
y_test = data_test.iloc[:,-1]
X_test = data_test.drop(['Salary'], axis=1)

# %%
X_test.head()
# Out:
#    age  workclass  educationno  maritalstatus  occupation  relationship  race  \
# 0   25          2            7              4           6             3     2
# 1   38          2            9              2           4             0     4
# 2   28          1           12              2          10             0     4
# 3   44          2           10              2           6             0     2
# 4   34          2            6              4           7             1     4
#
#    sex  capitalgain  capitalloss  hoursperweek  native
# 0    1            0            0            40      37
# 1    1            0            0            50      37
# 2    1            0            0            40      37
# 3    1         7688            0            40      37
# 4    1            0            0            30      37

# %%
y_test.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Salary, dtype: int32

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((30161, 12), (30161,), (15060, 12), (15060,))

# %% [markdown]
# ## Building the model

# %%
clf = SVC()
param_grid = [{'kernel':['rbf'],'gamma':[0.5,0.1,0.01],'C':[0.01,0.001] }]
gsv = RandomizedSearchCV(clf,param_grid,n_iter=5,verbose=300)
gsv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5; 1/5] START C=0.001, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 1/5] END C=0.001, gamma=0.1, kernel=rbf;, score=0.751 total time= 1.0min
# [CV 2/5; 1/5] START C=0.001, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 1/5] END C=0.001, gamma=0.1, kernel=rbf;, score=0.751 total time= 1.0min
# [CV 3/5; 1/5] START C=0.001, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 1/5] END C=0.001, gamma=0.1, kernel=rbf;, score=0.751 total time= 1.1min
# [CV 4/5; 1/5] START C=0.001, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 1/5] END C=0.001, gamma=0.1, kernel=rbf;, score=0.751 total time= 1.1min
# [CV 5/5; 1/5] START C=0.001, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 1/5] END C=0.001, gamma=0.1, kernel=rbf;, score=0.751 total time= 1.0min
# [CV 1/5; 2/5] START C=0.01, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 2/5] END C=0.01, gamma=0.1, kernel=rbf;, score=0.751 total time= 2.0min
# [CV 2/5; 2/5] START C=0.01, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 2/5] END C=0.01, gamma=0.1, kernel=rbf;, score=0.751 total time= 1.9min
# [CV 3/5; 2/5] START C=0.01, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 2/5] END C=0.01, gamma=0.1, kernel=rbf;, score=0.751 total time= 2.1min
# [CV 4/5; 2/5] START C=0.01, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 2/5] END C=0.01, gamma=0.1, kernel=rbf;, score=0.751 total time= 2.0min
# [CV 5/5; 2/5] START C=0.01, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 2/5] END C=0.01, gamma=0.1, kernel=rbf;, score=0.751 total time= 2.1min
# [CV 1/5; 3/5] START C=0.001, gamma=0.01, kernel=rbf.............................
# [CV 1/5; 3/5] END C=0.001, gamma=0.01, kernel=rbf;, score=0.751 total time= 1.2min
# [CV 2/5; 3/5] START C=0.001, gamma=0.01, kernel=rbf.............................
# [CV 2/5; 3/5] END C=0.001, gamma=0.01, kernel=rbf;, score=0.751 total time= 1.1min
# [CV 3/5; 3/5] START C=0.001, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 3/5] END C=0.001, gamma=0.01, kernel=rbf;, score=0.751 total time= 1.2min
# [CV 4/5; 3/5] START C=0.001, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 3/5] END C=0.001, gamma=0.01, kernel=rbf;, score=0.751 total time= 1.3min
# [CV 5/5; 3/5] START C=0.001, gamma=0.01, kernel=rbf.............................
# [CV 5/5; 3/5] END C=0.001, gamma=0.01, kernel=rbf;, score=0.751 total time= 1.4min
# [CV 1/5; 4/5] START C=0.01, gamma=0.5, kernel=rbf...............................
# [CV 1/5; 4/5] END C=0.01, gamma=0.5, kernel=rbf;, score=0.751 total time= 2.9min
# [CV 2/5; 4/5] START C=0.01, gamma=0.5, kernel=rbf...............................
# [CV 2/5; 4/5] END C=0.01, gamma=0.5, kernel=rbf;, score=0.751 total time= 2.8min
# [CV 3/5; 4/5] START C=0.01, gamma=0.5, kernel=rbf...............................
# [CV 3/5; 4/5] END C=0.01, gamma=0.5, kernel=rbf;, score=0.751 total time= 1.3min
# [CV 4/5; 4/5] START C=0.01, gamma=0.5, kernel=rbf...............................
# [CV 4/5; 4/5] END C=0.01, gamma=0.5, kernel=rbf;, score=0.751 total time= 1.1min
# [CV 5/5; 4/5] START C=0.01, gamma=0.5, kernel=rbf...............................
# [CV 5/5; 4/5] END C=0.01, gamma=0.5, kernel=rbf;, score=0.751 total time= 1.9min
# [CV 1/5; 5/5] START C=0.001, gamma=0.5, kernel=rbf..............................
# [CV 1/5; 5/5] END C=0.001, gamma=0.5, kernel=rbf;, score=0.751 total time=  44.2s
# [CV 2/5; 5/5] START C=0.001, gamma=0.5, kernel=rbf..............................
# [CV 2/5; 5/5] END C=0.001, gamma=0.5, kernel=rbf;, score=0.751 total time=  58.7s
# [CV 3/5; 5/5] START C=0.001, gamma=0.5, kernel=rbf..............................
# [CV 3/5; 5/5] END C=0.001, gamma=0.5, kernel=rbf;, score=0.751 total time= 1.4min
# [CV 4/5; 5/5] START C=0.001, gamma=0.5, kernel=rbf..............................
# [CV 4/5; 5/5] END C=0.001, gamma=0.5, kernel=rbf;, score=0.751 total time= 1.1min
# [CV 5/5; 5/5] START C=0.001, gamma=0.5, kernel=rbf..............................
# [CV 5/5; 5/5] END C=0.001, gamma=0.5, kernel=rbf;, score=0.751 total time=  48.7s
# RandomizedSearchCV(estimator=SVC(), n_iter=5,
#                    param_distributions=[{'C': [0.01, 0.001],
#                                          'gamma': [0.5, 0.1, 0.01],
#                                          'kernel': ['rbf']}],
#                    verbose=300)

# %%
gsv.best_params_ , gsv.best_score_
# Out:
# ({'kernel': 'rbf', 'gamma': 0.1, 'C': 0.001}, 0.7510692627331288)

# %%
final_model = SVC(kernel ='rbf', gamma = 0.1, C=0.001)
final_model.fit(X_train, y_train)
y_pred_with_rbf = final_model.predict(X_test)
score_rbf = accuracy_score(y_pred_with_rbf, y_test)
print(score_rbf)
# Out:
# 0.7543160690571049

# %% [markdown]
# ### Build a model by taking gamma and C from above and using linear kernel
# Eventually it is giving us better accuracy score.

# %%
## just wanted to have an idea what is the score and time taken for linear kernel
from sklearn.model_selection import KFold, cross_val_score
model_withlinearkernel = SVC(kernel ='linear', gamma = 0.1, C=0.001)
result = cross_val_score(model_withlinearkernel, X_train, y_train, cv=KFold(n_splits=5))
result.mean()
# Out:
# 0.8054441014297579

# %%
model_withlinearkernel.fit(X_train, y_train)
y_predict_with_linearkernel = model_withlinearkernel.predict(X_test)
score_linear = accuracy_score(y_test, y_predict_with_linearkernel)
print(score_linear)
# Out:
# 0.804316069057105
# 0.804316069057105
